# %% [markdown]
# # Comparison Operations
# ##

# %%
1 == 1
# Out:
# True

# %%
408 > 508
# Out:
# False

# %%
2 < 3
# Out:
# True

# %%
1 < 2 > 3
# Out:
# False

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
's' == 's' and 's' != 'S'
# Out:
# True

# %%
not (1 == 1)
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %% [markdown]
# # OS MODULES

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\shiva\\python\\dear-comrade-python-zero-to-hero\\data_science'

# %%
os.listdir()
# Out:
# ['data_science_1.ipynb', 'data_science_2_os_module.ipynb']

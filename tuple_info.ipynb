# %%
cricketer_names_gen = ('Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith', 'Rohith')
print(cricketer_names_gen)
# Out:
# ('Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith', 'Rohith')

# %%
print(len(cricketer_names_gen))
# Out:
# 10

# %%
"""
This will not work as tuple is immutable
"""
cricketer_names_gen[0] = "ABC"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 """
#       2 This will not work as tuple is immutable
#       3 """
# ----> 4 cricketer_names_gen[0] = "ABC"
#
# TypeError: 'tuple' object does not support item assignment

# %%
cricketer_names = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
for name in cricketer_names:
    print(name)
# Out:
# Sachin
# Ganguly
# Laxman
# Dravid
# Lara
# Kife
# Rabbin singh
# Shree nath
# Rohith

# %%
cricketer_names = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
has_rohit = "Rohith" in cricketer_names
print(has_rohit)
# Out:
# True

# %%
cricketer_names = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
print(cricketer_names)
cricketer_names.append("Gachibowli Diwakar")
print(cricketer_names)
# Out:
# ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith']
# ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith', 'Gachibowli Diwakar']

# %%
cricketer_names = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
new_player = "Gachibowli Diwakar"
if new_player in cricketer_names:
    print(f"{new_player} is already {cricketer_names}")
else:
    cricketer_names.append(new_player)
    print(f"{new_player} is added to {cricketer_names}")
# Out:
# Gachibowli Diwakar is added to ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith', 'Gachibowli Diwakar']

# %%
cricketer_names = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
length_of_list = len(cricketer_names)
print(length_of_list)
# Out:
# 9

# %%
cricketer_names = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
cricketer_names.insert(1, "Shiva")
print(cricketer_names)
# Out:
# ['Sachin', 'Shiva', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith']

# %%
cricketer_names = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
cricketer_names.insert(1, "Shiva")
print(cricketer_names)
cricketer_names[1] = "Dasari"
print(cricketer_names)
# Out:
# ['Sachin', 'Shiva', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith']
# ['Sachin', 'Dasari', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith']

# %%
cricketer_names_gen_1 = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
cricketer_names_gen_2 = ['Head', 'Klason']
cricketer_names_gen_1.extend(cricketer_names_gen_2)
print(cricketer_names_gen_1)
# Out:
# ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith', 'Head', 'Klason']

# %%
cricketer_names_gen_1 = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
cricketer_names_gen_2 = ['Head', 'Klason',"Shiva"]
cricketer_names_gen_1.extend(cricketer_names_gen_2)
cricketer_names_gen_1.remove("Shiva")
print(cricketer_names_gen_1)
# Out:
# ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath', 'Rohith', 'Head', 'Klason']

# %%
cricketer_names_gen_1 = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith']
cricketer_names_gen_1.clear()
print(cricketer_names_gen_1)
# Out:
# []

# %%
cricketer_names_gen_1 = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith', 'Rohith']
print(cricketer_names_gen_1.count("Rohith"))
# Out:
# 2

# %%
cricketer_names_gen_1 = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith', 'Rohith']
cricketer_names_gen_1.sort()
print(cricketer_names_gen_1)
# Out:
# ['Dravid', 'Ganguly', 'Kife', 'Lara', 'Laxman', 'Rabbin singh', 'Rohith', 'Rohith', 'Sachin', 'Shree nath']

# %%
cricketer_names_gen_1 = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith', 'Rohith']
cricketer_names_gen_1.sort(reverse=True)
print(cricketer_names_gen_1)
# Out:
# ['Shree nath', 'Sachin', 'Rohith', 'Rohith', 'Rabbin singh', 'Laxman', 'Lara', 'Kife', 'Ganguly', 'Dravid']

# %%
cricketer_names_gen = ['Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith', 'Rohith']
cricketer_names_gen_copy = cricketer_names_gen.copy()
cricketer_names_gen.sort()
cricketer_names_gen_copy.sort(reverse=True)
print(cricketer_names_gen)
print(cricketer_names_gen_copy)
# Out:
# ['Dravid', 'Ganguly', 'Kife', 'Lara', 'Laxman', 'Rabbin singh', 'Rohith', 'Rohith', 'Sachin', 'Shree nath']
# ['Shree nath', 'Sachin', 'Rohith', 'Rohith', 'Rabbin singh', 'Laxman', 'Lara', 'Kife', 'Ganguly', 'Dravid']

# %%
for x in "snorkel":
    print(x)
# Out:
# s
# n
# o
# r
# k
# e
# l

# %%
list_of_names = ["Shiva", "Dasari", "Java", "Python"]
for name in list_of_names:
    print(name)
print("Loop completed")
# Out:
# Shiva
# Dasari
# Java
# Python
# Loop completed

# %%
list_of_names = ["Shiva", "Dasari", "", "Java", "Python"]
for name in list_of_names:
    if name == "":
        print("Break condition detected")
        break
    print(name)
print("Loop completed")
# Out:
# Shiva
# Dasari
# Break condition detected
# Loop completed

# %%
list_of_names = ["Shiva", "Dasari", "", "Java", "Python"]
for name in list_of_names:
    if name == "":
        print("Break condition detected")
        continue
    print(name)
print("Loop completed")
# Out:
# Shiva
# Dasari
# Break condition detected
# Java
# Python
# Loop completed

# %%
def display_game(row_one,row_two, row_three):
    print(row_one)
    print(row_two)
    print(row_three)

# %%
row_one = ["_", "_", "_"]
row_two = ["_", "_", "_"]
row_three = ["_", "_", "_"]

# %%
row_two[1] = "X"

# %%
display_game(row_one, row_two, row_three)
# Out:
# ['_', '_', '_']
# ['_', 'X', '_']
# ['_', '_', '_']

# %%
input("Press enter to exit the game")
# Out:
# 'E'

# %%
cell_value = input("Enter the cell value: ")

# %%
cell_value
# Out:
# '6'

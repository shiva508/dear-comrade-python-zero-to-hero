# %%
try:
    file_info = open("cricket.txt", "r" , encoding="utf-8")
    for line in file_info:
        print(line)
except FileNotFoundError:
    print("File not found")
finally:
    file_info.close()
# Out:
# Shiva Dasari
#
# Satish Dasari
#
# మీరు ఎలా ఉన్నారు

# %%
try:
    with open("cricket.txt", "r", encoding="utf-8") as file:
        file_content = file.read()
        print(file_content)
except FileNotFoundError:
    print("File not found")
# Out:
# Shiva Dasari
# Satish Dasari
# మీరు ఎలా ఉన్నారు

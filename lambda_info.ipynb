# %%
def square_root(num):
    return num **2

# %%
def square_root(num): return num **2

# %%
square_root = lambda num: num **2

# %%
square_root(6)
# Out:
# 36

# %%
list(map(lambda num:num**2, [1,2,3,4,5]))
# Out:
# [1, 4, 9, 16, 25]

# %%
list(filter(lambda num:num**2, [1,2,3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

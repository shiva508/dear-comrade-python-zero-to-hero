# %%
"hello world"
# Out:
# 'hello world'

# %%
'Hello shiva'
# Out:
# 'Hello shiva'

# %%
"I'm sorry I don't understand"
# Out:
# "I'm sorry I don't understand"

# %%
print("Shekar \nkammula")
# Out:
# Shekar
# kammula

# %%
len("Shekar \nkammula")
# Out:
# 15

# %%
nama='Hello shiva'
print(nama)
# Out:
# Hello shiva

# %%
nama[0]
# Out:
# 'H'

# %%
nama[-1]
# Out:
# 'a'

# %%
nama[2:]
# Out:
# 'llo shiva'

# %%
nama[:2]
# Out:
# 'He'

# %%
nama[2:4]
# Out:
# 'll'

# %%
nama[::2]
# Out:
# 'Hlosia'

# %%
nama[2:7:2]
# Out:
# 'los'

# %%
nama[::-1]
# Out:
# 'avihs olleH'

# %%
repeat_name = nama* 20
print(repeat_name)
# Out:
# Hello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shivaHello shiva

# %%
is_there = "s" in repeat_name
print(is_there)
# Out:
# True

# %%
is_not_there = "x" not in repeat_name
print(is_not_there)
# Out:
# True

# %%
nama.index("a")
# Out:
# 10

# %%
nama.count("a")
# Out:
# 1

# %%
# Out:
# 1

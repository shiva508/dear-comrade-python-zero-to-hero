# %%
"hello world"
# Out:
# 'hello world'

# %%
'Hello shiva'
# Out:
# 'Hello shiva'

# %%
"I'm sorry I don't understand"
# Out:
# "I'm sorry I don't understand"

# %%
print("Shekar \nkammula")
# Out:
# Shekar
# kammula

# %%
len("Shekar \nkammula")
# Out:
# 15

# %%
nama='Hello shiva'
print(nama)
# Out:
# Hello shiva

# %%
nama[0]
# Out:
# 'H'

# %%
nama[-1]
# Out:
# 'a'

# %%
nama[2:]
# Out:
# 'llo shiva'

# %%
nama[:2]
# Out:
# 'He'

# %%
nama[2:4]
# Out:
# 'll'

# %%
nama[::2]
# Out:
# 'Hlosia'

# %%
nama[2:7:2]
# Out:
# 'los'

# %%
nama[::-1]
# Out:
# 'avihs olleH'

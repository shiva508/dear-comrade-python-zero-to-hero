# %%
is_it_ok = False
if(is_it_ok): print("It is ok")

# %%
is_it_ok = False
if is_it_ok:
    print("It is ok")
else:
    print("It is no")
# Out:
# It is no

# %%
colour = "blue"
if colour == "red":
    print("The colour is red")
elif colour == "green":
    print("The colour is green")
elif colour == "blue":
    print("The colour is blue")
else:
    print("The colour is not red")
# Out:
# The colour is blue

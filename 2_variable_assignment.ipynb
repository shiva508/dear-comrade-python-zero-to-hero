# %% [markdown]
# # Variable assignment

# %%
b_tech_roll_no = 408
b_tech_roll_no = ["408", "423"]

# %%
my_friend_names = ["Alice", "Bob", "Charlie"]
print(my_friend_names)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
my_friend_names = 508
print(my_friend_names)
# Out:
# 508

# %%
my_friend_names = my_friend_names * my_friend_names
print(my_friend_names)
# Out:
# 258064

# %%
sum = 508+408
print(sum)
# Out:
# 916

# %%
my_dogs = 2
print(my_dogs)
my_dogs = ["Rolex", "Tony"]
print(my_dogs)
# Out:
# 2
# ['Rolex', 'Tony']

# %%
a = 508
b = 408
sum = a+b
print(sum)
# Out:
# 916

# %%
type_of_sum = type(sum)
print(type_of_sum)
my_dogs = ["Rolex", "Tony"]
type(my_dogs)
# Out:
# <class 'builtin_function_or_method'>
# list

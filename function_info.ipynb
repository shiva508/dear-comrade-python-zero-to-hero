# %%
import math as m

# %%
def get_users():
    """
    This function gets users info
    """
    print("Users:")

# %%
get_users()
# Out:
# Users:

# %%
user = {"name": "shiva", "age": 35}

# %%
def display_user(user_input={"name": "Batman", "age": 35}):
    print(user_input["name"])

# %%
display_user(user)
# Out:
# shiva

# %%
display_user()
# Out:
# Batman

# %%
def display_user(user_input={"name": "Batman", "age": 35}):
    return user_input["name"]

name = display_user(user_input={"name": "Batman", "age": 35})
print(name)
# Out:
# Batman

# %%
cricketer_names = {'Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith'}
print(cricketer_names)
# Out:
# {'Ganguly', 'Dravid', 'Sachin', 'Shree nath', 'Rohith', 'Lara', 'Rabbin singh', 'Kife', 'Laxman'}

# %%
cricketer_names = {'Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith'}
cricketer_names.add('Shiva')
print(cricketer_names)
# Out:
# {'Ganguly', 'Dravid', 'Sachin', 'Shree nath', 'Rohith', 'Lara', 'Rabbin singh', 'Shiva', 'Kife', 'Laxman'}

# %%
cricketer_names = {'Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith'}
cricketer_names.update(["Dasari", "Shiva"])
print(cricketer_names)
# Out:
# {'Kife', 'Dravid', 'Dasari', 'Sachin', 'Shree nath', 'Rohith', 'Lara', 'Rabbin singh', 'Shiva', 'Ganguly', 'Laxman'}

# %%
cricketer_names = {'Sachin', 'Ganguly', 'Laxman', 'Dravid', 'Lara', 'Kife', 'Rabbin singh', 'Shree nath','Rohith'}
print(cricketer_names)
cricketer_names_gen_copy = cricketer_names.copy()
print(cricketer_names_gen_copy)
# Out:
# {'Kife', 'Dravid', 'Sachin', 'Shree nath', 'Rohith', 'Lara', 'Rabbin singh', 'Ganguly', 'Laxman'}
# {'Kife', 'Dravid', 'Sachin', 'Shree nath', 'Rohith', 'Lara', 'Rabbin singh', 'Ganguly', 'Laxman'}
